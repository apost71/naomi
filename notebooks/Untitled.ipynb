# %%
import pandas as pd

df_j2 = pd.read_csv("../test_sym_prop_j2.csv")
# df_no_forces = pd.read_csv("../test_no_forces.csv")

# %%
df_j2.head()
# Out:
#            x          y          z       vx       vy        vz
# 0  3900000.0  3900000.0  3900000.0 -5431.77  5431.77    0.0000
# 1  3845430.0  3954070.0  3899740.0 -5481.37  5381.47  -51.4069
# 2  3790370.0  4007630.0  3898970.0 -5530.26  5330.49 -102.8070
# 3  3734830.0  4060670.0  3897690.0 -5578.45  5278.82 -154.1950
# 4  3678810.0  4113200.0  3895890.0 -5625.93  5226.48 -205.5630

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(df_j2.index, df_j2["x"], s=10, c='b', label='x')
ax1.scatter(df_j2.index, df_j2["y"], s=10, c='r', label='y')
ax1.scatter(df_j2.index, df_j2["z"], s=10, c='g', label='z')

plt.legend(loc='upper left')
plt.show()
